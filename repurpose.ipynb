# %% [markdown]
# # Repurpose: A Python-based platform for reproducible similarity-based drug repurposing
#
# Over the past years many methods for similarity-based (a.k.a. knowledge-based,
# guilt-by-association-based) drug repurposing, yet most of these studies do not
# provide the code or the model used in the study. To improve reproducibility,
# we present a Python-platform offering
# - drug feature data parsing and similarity calculation
# - data balancing
# - (disjoint) cross validation
# - classifier building
#
# Using this platform we investigate the effect using unseen data in the test
# set in similarity-based classification.
#
#
# ## Requiremets
# The Python platform has the following dependencies:
#
# - [Numpy](http://www.numpy.org)
# - [Scikit-learn](http://scikit-learn.org)
#
#
# ## Data sets
# The data sets used in the analysis are freely available
# [online](http://astro.temple.edu/~tua87106/drugreposition.html)
#
# We have modified these data sets slightly for parsing in Python by
# - converting all drug, disease and side effect terms to lowercase
# - removing the quotations and making the text tab delimited
# - we also added the 'Drug' text to the header
#
# These modified files are available under _'data/'_ folder.
#
# ## Setting up the platform

# %%
import random
from src import ml, utilities
from toolbox import configuration

# Get parameters
#random.seed(52345) # for reproducibility
features = ["chemical", "target", "phenotype"]
model_type = "logistic" # ML model
prediction_type = "disease" # predict drug-disease associations
output_file = "data/validation.dat.test" # file containing run parameters and corresponding AUC values
n_proportion = 2 # proportion of negative instances compared to positives
n_subset = -1 # for faster results - subsampling data
knn = 20 # number of nearest drugs to check in the pharmacological space to assing a repurposing score
n_run = 10 # number of repetitions of cross-validation analysis
n_fold = 10 # number of folds in cross-validation
recalculate_similarity = True # whether the k-NN based repurposing score should be calculated within the training/test set
# whether the drugs in the drug-disease pairs of the cross-validation folds should be non-overlapping disjoint_cv = False 
disjoint_cv = False 

# Get data
drug_disease_file = "data/drug_disease.dat"
drug_side_effect_file = "data/drug_sider.dat"
drug_structure_file = "data/drug_structure.dat"
drug_target_file = "data/drug_protein.dat"
data = utilities.get_data(drug_disease_file, drug_side_effect_file, drug_structure_file, drug_target_file)

# %% [markdown]
# ## Evaluating the effect of each feature in prediction performance

# %%
features = ["chemical", "target", "phenotype"]

for feature in features:
    features_modified = [ feature ]
    print feature
    # Check prediction accuracy of ML classifier on the data set using the parameters above
    ml.check_ml(data, n_run, knn, n_fold, n_proportion, n_subset, model_type, prediction_type, features_modified, recalculate_similarity, disjoint_cv, output_file, model_fun = None)
# Out:
# chemical
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# AUC over runs: 77.4 (+/-0.2): [77.6, 77.3, 77.1, 77.2, 77.2, 77.4, 77.4, 77.6, 77.3, 77.5]
# target
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# AUC over runs: 76.9 (+/-0.2): [76.8, 76.9, 76.9, 76.6, 76.9, 77.1, 77.1, 77.1, 76.9, 76.7]
# phenotype
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# AUC over runs: 80.0 (+/-0.3): [80.4, 79.8, 80.3, 80.2, 80.3, 80.4, 79.8, 80.1, 79.7, 79.4]

# %% [markdown]
# ## Evaluating the effect of data imbalance

# %%
n_fold = 10 # number of folds in cross-validation

# proportion of negative instances compared to positives
for n_proportion in [ 1, 2, 5, 20 ]: 
    print n_proportion
    # Check prediction accuracy of ML classifier on the data set using the parameters above
    ml.check_ml(data, n_run, knn, n_fold, n_proportion, n_subset, model_type, prediction_type, features, recalculate_similarity, disjoint_cv, output_file, model_fun = None)
# Out:
# 1
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# AUC over runs: 83.0 (+/-0.3): [83.1, 83.3, 83.2, 82.7, 83.1, 83.2, 83.4, 83.1, 82.4, 82.7]
# 2
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# AUC over runs: 84.1 (+/-0.2): [84.5, 84.1, 84.1, 83.7, 84.0, 84.3, 84.3, 83.9, 84.3, 84.2]
# 5
# 536

# %% [markdown]
# ## Evaluating the effect of number of folds in cross validation

# %%
n_proportion = 2 # proportion of negative instances compared to positives

# number of folds in cross-validation
for n_fold in [ 2, 5, 10, 20 ]: 
    print n_fold
    # Check prediction accuracy of ML classifier on the data set using the parameters above
    # Use verbose argument for per cross-validation metrics
    ml.check_ml(data, n_run, knn, n_fold, n_proportion, n_subset, model_type, prediction_type, features, recalculate_similarity, disjoint_cv, output_file, model_fun = None, verbose = True)
# Out:
# 2
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# Fold: 1 # train: 3343 # test: 3344 AUC: 85.5 AUPRC: 84.8
# Fold: 2 # train: 3344 # test: 3343 AUC: 85.0 AUPRC: 85.2
# Fold: 1 # train: 3343 # test: 3344 AUC: 85.1 AUPRC: 84.9
# Fold: 2 # train: 3344 # test: 3343 AUC: 85.8 AUPRC: 85.7
# Fold: 1 # train: 3343 # test: 3344 AUC: 85.5 AUPRC: 85.2
# Fold: 2 # train: 3344 # test: 3343 AUC: 85.3 AUPRC: 85.7
# Fold: 1 # train: 3343 # test: 3344 AUC: 86.2 AUPRC: 85.8
# Fold: 2 # train: 3344 # test: 3343 AUC: 84.7 AUPRC: 84.7
# Fold: 1 # train: 3343 # test: 3344 AUC: 84.8 AUPRC: 85.0
# Fold: 2 # train: 3344 # test: 3343 AUC: 86.3 AUPRC: 86.0
# Fold: 1 # train: 3343 # test: 3344 AUC: 84.7 AUPRC: 84.9
# Fold: 2 # train: 3344 # test: 3343 AUC: 86.7 AUPRC: 87.0
# Fold: 1 # train: 3343 # test: 3344 AUC: 85.7 AUPRC: 85.5
# Fold: 2 # train: 3344 # test: 3343 AUC: 85.3 AUPRC: 85.4
# Fold: 1 # train: 3343 # test: 3344 AUC: 85.9 AUPRC: 85.7
# Fold: 2 # train: 3344 # test: 3343 AUC: 84.8 AUPRC: 84.7
# Fold: 1 # train: 3343 # test: 3344 AUC: 85.0 AUPRC: 85.4
# Fold: 2 # train: 3344 # test: 3343 AUC: 85.9 AUPRC: 85.8
# Fold: 1 # train: 3343 # test: 3344 AUC: 85.2 AUPRC: 85.2
# Fold: 2 # train: 3344 # test: 3343 AUC: 85.9 AUPRC: 85.8
# AUC over runs: 85.5 (+/-0.1): [85.2, 85.4, 85.4, 85.5, 85.5, 85.7, 85.5, 85.3, 85.4, 85.6]
# 5
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# Fold: 1 # train: 5349 # test: 1338 AUC: 86.0 AUPRC: 86.0
# Fold: 2 # train: 5349 # test: 1338 AUC: 83.1 AUPRC: 82.0
# Fold: 3 # train: 5349 # test: 1338 AUC: 85.0 AUPRC: 84.7
# Fold: 4 # train: 5350 # test: 1337 AUC: 85.4 AUPRC: 85.7
# Fold: 5 # train: 5351 # test: 1336 AUC: 87.2 AUPRC: 86.5
# Fold: 1 # train: 5349 # test: 1338 AUC: 85.9 AUPRC: 85.4
# Fold: 2 # train: 5349 # test: 1338 AUC: 83.9 AUPRC: 84.5
# Fold: 3 # train: 5349 # test: 1338 AUC: 87.4 AUPRC: 87.0
# Fold: 4 # train: 5350 # test: 1337 AUC: 83.5 AUPRC: 82.4
# Fold: 5 # train: 5351 # test: 1336 AUC: 85.2 AUPRC: 84.3
# Fold: 1 # train: 5349 # test: 1338 AUC: 84.4 AUPRC: 83.9
# Fold: 2 # train: 5349 # test: 1338 AUC: 84.0 AUPRC: 83.6
# Fold: 3 # train: 5349 # test: 1338 AUC: 84.7 AUPRC: 84.6
# Fold: 4 # train: 5350 # test: 1337 AUC: 85.8 AUPRC: 85.7
# Fold: 5 # train: 5351 # test: 1336 AUC: 87.3 AUPRC: 86.4
# Fold: 1 # train: 5349 # test: 1338 AUC: 86.4 AUPRC: 87.0
# Fold: 2 # train: 5349 # test: 1338 AUC: 84.8 AUPRC: 84.7
# Fold: 3 # train: 5349 # test: 1338 AUC: 86.6 AUPRC: 86.0
# Fold: 4 # train: 5350 # test: 1337 AUC: 84.8 AUPRC: 84.8
# Fold: 5 # train: 5351 # test: 1336 AUC: 85.2 AUPRC: 84.8
# Fold: 1 # train: 5349 # test: 1338 AUC: 85.6 AUPRC: 85.3
# Fold: 2 # train: 5349 # test: 1338 AUC: 84.9 AUPRC: 84.0
# Fold: 3 # train: 5349 # test: 1338 AUC: 85.1 AUPRC: 84.8
# Fold: 4 # train: 5350 # test: 1337 AUC: 86.3 AUPRC: 85.6
# Fold: 5 # train: 5351 # test: 1336 AUC: 84.2 AUPRC: 83.6
# Fold: 1 # train: 5349 # test: 1338 AUC: 84.9 AUPRC: 85.1
# Fold: 2 # train: 5349 # test: 1338 AUC: 84.1 AUPRC: 84.5
# Fold: 3 # train: 5349 # test: 1338 AUC: 85.0 AUPRC: 84.0
# Fold: 4 # train: 5350 # test: 1337 AUC: 85.0 AUPRC: 85.3
# Fold: 5 # train: 5351 # test: 1336 AUC: 86.9 AUPRC: 86.5
# Fold: 1 # train: 5349 # test: 1338 AUC: 87.0 AUPRC: 87.1
# Fold: 2 # train: 5349 # test: 1338 AUC: 85.8 AUPRC: 85.8
# Fold: 3 # train: 5349 # test: 1338 AUC: 85.5 AUPRC: 85.3
# Fold: 4 # train: 5350 # test: 1337 AUC: 84.2 AUPRC: 84.2
# Fold: 5 # train: 5351 # test: 1336 AUC: 85.0 AUPRC: 84.9
# Fold: 1 # train: 5349 # test: 1338 AUC: 85.6 AUPRC: 85.9
# Fold: 2 # train: 5349 # test: 1338 AUC: 84.4 AUPRC: 84.8
# Fold: 3 # train: 5349 # test: 1338 AUC: 86.3 AUPRC: 85.6
# Fold: 4 # train: 5350 # test: 1337 AUC: 86.5 AUPRC: 86.2
# Fold: 5 # train: 5351 # test: 1336 AUC: 83.9 AUPRC: 84.1
# Fold: 1 # train: 5349 # test: 1338 AUC: 85.4 AUPRC: 84.7
# Fold: 2 # train: 5349 # test: 1338 AUC: 85.5 AUPRC: 85.7
# Fold: 3 # train: 5349 # test: 1338 AUC: 85.0 AUPRC: 84.6
# Fold: 4 # train: 5350 # test: 1337 AUC: 86.1 AUPRC: 86.4
# Fold: 5 # train: 5351 # test: 1336 AUC: 84.2 AUPRC: 84.4
# Fold: 1 # train: 5349 # test: 1338 AUC: 85.1 AUPRC: 85.1
# Fold: 2 # train: 5349 # test: 1338 AUC: 84.8 AUPRC: 84.4
# Fold: 3 # train: 5349 # test: 1338 AUC: 83.2 AUPRC: 82.0
# Fold: 4 # train: 5350 # test: 1337 AUC: 85.9 AUPRC: 86.3
# Fold: 5 # train: 5351 # test: 1336 AUC: 86.2 AUPRC: 85.9
# AUC over runs: 85.3 (+/-0.1): [85.3, 85.2, 85.2, 85.5, 85.2, 85.2, 85.5, 85.3, 85.2, 85.0]
# 10
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# Fold: 1 # train: 6018 # test: 669 AUC: 81.7 AUPRC: 81.5
# Fold: 2 # train: 6018 # test: 669 AUC: 82.3 AUPRC: 80.7
# Fold: 3 # train: 6018 # test: 669 AUC: 85.1 AUPRC: 83.6
# Fold: 4 # train: 6018 # test: 669 AUC: 86.5 AUPRC: 86.6
# Fold: 5 # train: 6018 # test: 669 AUC: 86.4 AUPRC: 86.6
# Fold: 6 # train: 6018 # test: 669 AUC: 84.4 AUPRC: 83.3
# Fold: 7 # train: 6018 # test: 669 AUC: 85.3 AUPRC: 84.8
# Fold: 8 # train: 6018 # test: 669 AUC: 81.2 AUPRC: 81.8
# Fold: 9 # train: 6019 # test: 668 AUC: 86.8 AUPRC: 86.3
# Fold: 10 # train: 6020 # test: 667 AUC: 82.4 AUPRC: 81.8
# Fold: 1 # train: 6018 # test: 669 AUC: 85.5 AUPRC: 84.4
# Fold: 2 # train: 6018 # test: 669 AUC: 84.8 AUPRC: 84.3
# Fold: 3 # train: 6018 # test: 669 AUC: 81.9 AUPRC: 81.7
# Fold: 4 # train: 6018 # test: 669 AUC: 84.2 AUPRC: 83.4
# Fold: 5 # train: 6018 # test: 669 AUC: 79.7 AUPRC: 80.4
# Fold: 6 # train: 6018 # test: 669 AUC: 84.5 AUPRC: 83.9
# Fold: 7 # train: 6018 # test: 669 AUC: 84.5 AUPRC: 84.2
# Fold: 8 # train: 6018 # test: 669 AUC: 85.0 AUPRC: 84.8
# Fold: 9 # train: 6019 # test: 668 AUC: 84.2 AUPRC: 82.5
# Fold: 10 # train: 6020 # test: 667 AUC: 83.6 AUPRC: 81.6
# Fold: 1 # train: 6018 # test: 669 AUC: 86.8 AUPRC: 86.1
# Fold: 2 # train: 6018 # test: 669 AUC: 84.2 AUPRC: 84.3
# Fold: 3 # train: 6018 # test: 669 AUC: 81.3 AUPRC: 82.3
# Fold: 4 # train: 6018 # test: 669 AUC: 85.6 AUPRC: 84.8
# Fold: 5 # train: 6018 # test: 669 AUC: 83.6 AUPRC: 83.1
# Fold: 6 # train: 6018 # test: 669 AUC: 85.4 AUPRC: 85.6
# Fold: 7 # train: 6018 # test: 669 AUC: 83.4 AUPRC: 83.3
# Fold: 8 # train: 6018 # test: 669 AUC: 85.3 AUPRC: 85.3
# Fold: 9 # train: 6019 # test: 668 AUC: 83.9 AUPRC: 83.8
# Fold: 10 # train: 6020 # test: 667 AUC: 84.8 AUPRC: 85.1
# Fold: 1 # train: 6018 # test: 669 AUC: 80.2 AUPRC: 79.3
# Fold: 2 # train: 6018 # test: 669 AUC: 83.5 AUPRC: 82.5
# Fold: 3 # train: 6018 # test: 669 AUC: 84.1 AUPRC: 83.3
# Fold: 4 # train: 6018 # test: 669 AUC: 85.0 AUPRC: 82.8
# Fold: 5 # train: 6018 # test: 669 AUC: 82.1 AUPRC: 80.3
# Fold: 6 # train: 6018 # test: 669 AUC: 83.8 AUPRC: 82.5
# Fold: 7 # train: 6018 # test: 669 AUC: 84.9 AUPRC: 84.3
# Fold: 8 # train: 6018 # test: 669 AUC: 83.1 AUPRC: 82.6
# Fold: 9 # train: 6019 # test: 668 AUC: 81.7 AUPRC: 81.2
# Fold: 10 # train: 6020 # test: 667 AUC: 85.4 AUPRC: 85.3
# Fold: 1 # train: 6018 # test: 669 AUC: 84.0 AUPRC: 84.2
# Fold: 2 # train: 6018 # test: 669 AUC: 84.1 AUPRC: 84.4
# Fold: 3 # train: 6018 # test: 669 AUC: 85.2 AUPRC: 85.1
# Fold: 4 # train: 6018 # test: 669 AUC: 84.9 AUPRC: 84.7
# Fold: 5 # train: 6018 # test: 669 AUC: 84.6 AUPRC: 83.7
# Fold: 6 # train: 6018 # test: 669 AUC: 88.0 AUPRC: 87.3
# Fold: 7 # train: 6018 # test: 669 AUC: 83.5 AUPRC: 82.6
# Fold: 8 # train: 6018 # test: 669 AUC: 84.2 AUPRC: 83.1
# Fold: 9 # train: 6019 # test: 668 AUC: 83.7 AUPRC: 83.9
# Fold: 10 # train: 6020 # test: 667 AUC: 81.1 AUPRC: 80.9
# Fold: 1 # train: 6018 # test: 669 AUC: 83.1 AUPRC: 81.5
# Fold: 2 # train: 6018 # test: 669 AUC: 83.8 AUPRC: 81.8
# Fold: 3 # train: 6018 # test: 669 AUC: 84.6 AUPRC: 84.0
# Fold: 4 # train: 6018 # test: 669 AUC: 86.9 AUPRC: 84.8
# Fold: 5 # train: 6018 # test: 669 AUC: 85.3 AUPRC: 85.5
# Fold: 6 # train: 6018 # test: 669 AUC: 84.9 AUPRC: 84.1
# Fold: 7 # train: 6018 # test: 669 AUC: 82.3 AUPRC: 80.7
# Fold: 8 # train: 6018 # test: 669 AUC: 85.7 AUPRC: 84.8
# Fold: 9 # train: 6019 # test: 668 AUC: 84.2 AUPRC: 84.6
# Fold: 10 # train: 6020 # test: 667 AUC: 82.7 AUPRC: 81.9
# Fold: 1 # train: 6018 # test: 669 AUC: 83.1 AUPRC: 82.6
# Fold: 2 # train: 6018 # test: 669 AUC: 84.4 AUPRC: 83.6
# Fold: 3 # train: 6018 # test: 669 AUC: 85.5 AUPRC: 82.4
# Fold: 4 # train: 6018 # test: 669 AUC: 82.9 AUPRC: 83.4
# Fold: 5 # train: 6018 # test: 669 AUC: 85.3 AUPRC: 84.8
# Fold: 6 # train: 6018 # test: 669 AUC: 84.2 AUPRC: 83.8
# Fold: 7 # train: 6018 # test: 669 AUC: 81.6 AUPRC: 81.7
# Fold: 8 # train: 6018 # test: 669 AUC: 83.8 AUPRC: 82.7
# Fold: 9 # train: 6019 # test: 668 AUC: 83.1 AUPRC: 83.1
# Fold: 10 # train: 6020 # test: 667 AUC: 84.5 AUPRC: 84.2
# Fold: 1 # train: 6018 # test: 669 AUC: 84.9 AUPRC: 84.3
# Fold: 2 # train: 6018 # test: 669 AUC: 85.3 AUPRC: 85.3
# Fold: 3 # train: 6018 # test: 669 AUC: 83.7 AUPRC: 83.7
# Fold: 4 # train: 6018 # test: 669 AUC: 87.0 AUPRC: 86.2
# Fold: 5 # train: 6018 # test: 669 AUC: 85.9 AUPRC: 85.7
# Fold: 6 # train: 6018 # test: 669 AUC: 83.1 AUPRC: 83.2
# Fold: 7 # train: 6018 # test: 669 AUC: 80.8 AUPRC: 80.9
# Fold: 8 # train: 6018 # test: 669 AUC: 83.5 AUPRC: 84.1
# Fold: 9 # train: 6019 # test: 668 AUC: 86.2 AUPRC: 86.0
# Fold: 10 # train: 6020 # test: 667 AUC: 86.1 AUPRC: 85.6
# Fold: 1 # train: 6018 # test: 669 AUC: 83.2 AUPRC: 82.5
# Fold: 2 # train: 6018 # test: 669 AUC: 86.6 AUPRC: 85.4
# Fold: 3 # train: 6018 # test: 669 AUC: 87.2 AUPRC: 87.3
# Fold: 4 # train: 6018 # test: 669 AUC: 81.8 AUPRC: 81.0
# Fold: 5 # train: 6018 # test: 669 AUC: 84.0 AUPRC: 83.5
# Fold: 6 # train: 6018 # test: 669 AUC: 84.1 AUPRC: 83.2
# Fold: 7 # train: 6018 # test: 669 AUC: 81.9 AUPRC: 81.8
# Fold: 8 # train: 6018 # test: 669 AUC: 83.9 AUPRC: 83.9
# Fold: 9 # train: 6019 # test: 668 AUC: 84.0 AUPRC: 83.3
# Fold: 10 # train: 6020 # test: 667 AUC: 86.4 AUPRC: 85.2
# Fold: 1 # train: 6018 # test: 669 AUC: 85.5 AUPRC: 85.4
# Fold: 2 # train: 6018 # test: 669 AUC: 82.8 AUPRC: 83.2
# Fold: 3 # train: 6018 # test: 669 AUC: 82.4 AUPRC: 81.6
# Fold: 4 # train: 6018 # test: 669 AUC: 85.6 AUPRC: 85.6
# Fold: 5 # train: 6018 # test: 669 AUC: 84.7 AUPRC: 84.2
# Fold: 6 # train: 6018 # test: 669 AUC: 83.3 AUPRC: 83.1
# Fold: 7 # train: 6018 # test: 669 AUC: 83.9 AUPRC: 83.4
# Fold: 8 # train: 6018 # test: 669 AUC: 82.9 AUPRC: 81.6
# Fold: 9 # train: 6019 # test: 668 AUC: 83.6 AUPRC: 83.3
# Fold: 10 # train: 6020 # test: 667 AUC: 86.3 AUPRC: 84.4
# AUC over runs: 84.1 (+/-0.4): [84.2, 83.8, 84.4, 83.4, 84.3, 84.4, 83.8, 84.6, 84.3, 84.1]
# 20
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# Fold: 1 # train: 6352 # test: 335 AUC: 81.9 AUPRC: 79.6
# Fold: 2 # train: 6352 # test: 335 AUC: 82.5 AUPRC: 80.7
# Fold: 3 # train: 6352 # test: 335 AUC: 85.7 AUPRC: 85.3
# Fold: 4 # train: 6352 # test: 335 AUC: 83.7 AUPRC: 82.9
# Fold: 5 # train: 6352 # test: 335 AUC: 80.2 AUPRC: 77.6
# Fold: 6 # train: 6352 # test: 335 AUC: 83.6 AUPRC: 83.4
# Fold: 7 # train: 6352 # test: 335 AUC: 80.7 AUPRC: 79.6
# Fold: 8 # train: 6352 # test: 335 AUC: 85.0 AUPRC: 83.5
# Fold: 9 # train: 6352 # test: 335 AUC: 82.5 AUPRC: 83.2
# Fold: 10 # train: 6353 # test: 334 AUC: 84.8 AUPRC: 82.9
# Fold: 11 # train: 6353 # test: 334 AUC: 77.6 AUPRC: 78.0
# Fold: 12 # train: 6353 # test: 334 AUC: 82.3 AUPRC: 82.1
# Fold: 13 # train: 6353 # test: 334 AUC: 78.0 AUPRC: 76.9
# Fold: 14 # train: 6353 # test: 334 AUC: 77.9 AUPRC: 78.5
# Fold: 15 # train: 6353 # test: 334 AUC: 81.3 AUPRC: 80.3
# Fold: 16 # train: 6353 # test: 334 AUC: 85.4 AUPRC: 84.4
# Fold: 17 # train: 6353 # test: 334 AUC: 76.4 AUPRC: 75.0
# Fold: 18 # train: 6353 # test: 334 AUC: 80.1 AUPRC: 79.5
# Fold: 19 # train: 6354 # test: 333 AUC: 81.3 AUPRC: 80.0
# Fold: 20 # train: 6354 # test: 333 AUC: 84.3 AUPRC: 81.1
# Fold: 1 # train: 6352 # test: 335 AUC: 84.3 AUPRC: 83.2
# Fold: 2 # train: 6352 # test: 335 AUC: 81.7 AUPRC: 80.1
# Fold: 3 # train: 6352 # test: 335 AUC: 81.0 AUPRC: 79.4
# Fold: 4 # train: 6352 # test: 335 AUC: 82.5 AUPRC: 82.6
# Fold: 5 # train: 6352 # test: 335 AUC: 83.3 AUPRC: 81.6
# Fold: 6 # train: 6352 # test: 335 AUC: 82.8 AUPRC: 83.9
# Fold: 7 # train: 6352 # test: 335 AUC: 83.8 AUPRC: 83.8
# Fold: 8 # train: 6352 # test: 335 AUC: 78.3 AUPRC: 74.6
# Fold: 9 # train: 6352 # test: 335 AUC: 80.4 AUPRC: 80.1
# Fold: 10 # train: 6353 # test: 334 AUC: 84.0 AUPRC: 84.2
# Fold: 11 # train: 6353 # test: 334 AUC: 79.4 AUPRC: 79.0
# Fold: 12 # train: 6353 # test: 334 AUC: 80.1 AUPRC: 80.3
# Fold: 13 # train: 6353 # test: 334 AUC: 83.1 AUPRC: 83.2
# Fold: 14 # train: 6353 # test: 334 AUC: 81.9 AUPRC: 82.1
# Fold: 15 # train: 6353 # test: 334 AUC: 82.5 AUPRC: 82.2
# Fold: 16 # train: 6353 # test: 334 AUC: 79.8 AUPRC: 79.3
# Fold: 17 # train: 6353 # test: 334 AUC: 77.6 AUPRC: 77.3
# Fold: 18 # train: 6353 # test: 334 AUC: 80.2 AUPRC: 80.3
# Fold: 19 # train: 6354 # test: 333 AUC: 79.3 AUPRC: 78.5
# Fold: 20 # train: 6354 # test: 333 AUC: 87.5 AUPRC: 86.3
# Fold: 1 # train: 6352 # test: 335 AUC: 83.6 AUPRC: 83.1
# Fold: 2 # train: 6352 # test: 335 AUC: 77.8 AUPRC: 77.4
# Fold: 3 # train: 6352 # test: 335 AUC: 80.0 AUPRC: 81.2
# Fold: 4 # train: 6352 # test: 335 AUC: 81.8 AUPRC: 80.4
# Fold: 5 # train: 6352 # test: 335 AUC: 83.0 AUPRC: 82.6
# Fold: 6 # train: 6352 # test: 335 AUC: 82.4 AUPRC: 82.6
# Fold: 7 # train: 6352 # test: 335 AUC: 80.3 AUPRC: 80.4
# Fold: 8 # train: 6352 # test: 335 AUC: 82.5 AUPRC: 83.3
# Fold: 9 # train: 6352 # test: 335 AUC: 85.5 AUPRC: 85.3
# Fold: 10 # train: 6353 # test: 334 AUC: 82.7 AUPRC: 79.6
# Fold: 11 # train: 6353 # test: 334 AUC: 85.7 AUPRC: 85.9
# Fold: 12 # train: 6353 # test: 334 AUC: 84.0 AUPRC: 83.7
# Fold: 13 # train: 6353 # test: 334 AUC: 80.3 AUPRC: 78.5
# Fold: 14 # train: 6353 # test: 334 AUC: 82.6 AUPRC: 82.4
# Fold: 15 # train: 6353 # test: 334 AUC: 83.6 AUPRC: 83.2
# Fold: 16 # train: 6353 # test: 334 AUC: 78.8 AUPRC: 77.4
# Fold: 17 # train: 6353 # test: 334 AUC: 79.0 AUPRC: 80.0
# Fold: 18 # train: 6353 # test: 334 AUC: 77.0 AUPRC: 77.5
# Fold: 19 # train: 6354 # test: 333 AUC: 81.1 AUPRC: 79.8
# Fold: 20 # train: 6354 # test: 333 AUC: 77.6 AUPRC: 76.2
# Fold: 1 # train: 6352 # test: 335 AUC: 84.9 AUPRC: 84.4
# Fold: 2 # train: 6352 # test: 335 AUC: 86.8 AUPRC: 87.0
# Fold: 3 # train: 6352 # test: 335 AUC: 85.5 AUPRC: 85.5
# Fold: 4 # train: 6352 # test: 335 AUC: 83.2 AUPRC: 83.3
# Fold: 5 # train: 6352 # test: 335 AUC: 75.4 AUPRC: 74.4
# Fold: 6 # train: 6352 # test: 335 AUC: 77.0 AUPRC: 76.3
# Fold: 7 # train: 6352 # test: 335 AUC: 86.9 AUPRC: 87.7
# Fold: 8 # train: 6352 # test: 335 AUC: 77.8 AUPRC: 74.8
# Fold: 9 # train: 6352 # test: 335 AUC: 82.1 AUPRC: 81.9
# Fold: 10 # train: 6353 # test: 334 AUC: 83.1 AUPRC: 83.6
# Fold: 11 # train: 6353 # test: 334 AUC: 76.7 AUPRC: 75.4
# Fold: 12 # train: 6353 # test: 334 AUC: 80.2 AUPRC: 77.1
# Fold: 13 # train: 6353 # test: 334 AUC: 81.9 AUPRC: 81.8
# Fold: 14 # train: 6353 # test: 334 AUC: 80.2 AUPRC: 81.2
# Fold: 15 # train: 6353 # test: 334 AUC: 84.0 AUPRC: 82.6
# Fold: 16 # train: 6353 # test: 334 AUC: 80.2 AUPRC: 79.6
# Fold: 17 # train: 6353 # test: 334 AUC: 81.0 AUPRC: 81.3
# Fold: 18 # train: 6353 # test: 334 AUC: 82.0 AUPRC: 81.2
# Fold: 19 # train: 6354 # test: 333 AUC: 80.8 AUPRC: 80.7
# Fold: 20 # train: 6354 # test: 333 AUC: 78.4 AUPRC: 75.3
# Fold: 1 # train: 6352 # test: 335 AUC: 84.1 AUPRC: 82.9
# Fold: 2 # train: 6352 # test: 335 AUC: 84.5 AUPRC: 82.8
# Fold: 3 # train: 6352 # test: 335 AUC: 83.8 AUPRC: 83.9
# Fold: 4 # train: 6352 # test: 335 AUC: 82.8 AUPRC: 82.5
# Fold: 5 # train: 6352 # test: 335 AUC: 79.8 AUPRC: 79.6
# Fold: 6 # train: 6352 # test: 335 AUC: 85.6 AUPRC: 83.6
# Fold: 7 # train: 6352 # test: 335 AUC: 81.5 AUPRC: 82.3
# Fold: 8 # train: 6352 # test: 335 AUC: 80.7 AUPRC: 80.8
# Fold: 9 # train: 6352 # test: 335 AUC: 81.2 AUPRC: 79.7
# Fold: 10 # train: 6353 # test: 334 AUC: 77.1 AUPRC: 75.1
# Fold: 11 # train: 6353 # test: 334 AUC: 81.2 AUPRC: 79.7
# Fold: 12 # train: 6353 # test: 334 AUC: 72.4 AUPRC: 71.6
# Fold: 13 # train: 6353 # test: 334 AUC: 79.6 AUPRC: 78.3
# Fold: 14 # train: 6353 # test: 334 AUC: 81.7 AUPRC: 81.0
# Fold: 15 # train: 6353 # test: 334 AUC: 79.2 AUPRC: 77.4
# Fold: 16 # train: 6353 # test: 334 AUC: 82.2 AUPRC: 81.4
# Fold: 17 # train: 6353 # test: 334 AUC: 83.1 AUPRC: 81.3
# Fold: 18 # train: 6353 # test: 334 AUC: 81.2 AUPRC: 80.9
# Fold: 19 # train: 6354 # test: 333 AUC: 81.8 AUPRC: 79.3
# Fold: 20 # train: 6354 # test: 333 AUC: 79.1 AUPRC: 76.4
# Fold: 1 # train: 6352 # test: 335 AUC: 84.2 AUPRC: 83.4
# Fold: 2 # train: 6352 # test: 335 AUC: 81.1 AUPRC: 81.3
# Fold: 3 # train: 6352 # test: 335 AUC: 79.9 AUPRC: 80.1
# Fold: 4 # train: 6352 # test: 335 AUC: 80.2 AUPRC: 78.4
# Fold: 5 # train: 6352 # test: 335 AUC: 82.9 AUPRC: 81.3
# Fold: 6 # train: 6352 # test: 335 AUC: 83.3 AUPRC: 83.1
# Fold: 7 # train: 6352 # test: 335 AUC: 83.8 AUPRC: 84.1
# Fold: 8 # train: 6352 # test: 335 AUC: 82.4 AUPRC: 82.2
# Fold: 9 # train: 6352 # test: 335 AUC: 81.2 AUPRC: 79.9
# Fold: 10 # train: 6353 # test: 334 AUC: 86.1 AUPRC: 82.1
# Fold: 11 # train: 6353 # test: 334 AUC: 79.6 AUPRC: 79.7
# Fold: 12 # train: 6353 # test: 334 AUC: 83.1 AUPRC: 83.4
# Fold: 13 # train: 6353 # test: 334 AUC: 81.5 AUPRC: 81.2
# Fold: 14 # train: 6353 # test: 334 AUC: 83.4 AUPRC: 83.5
# Fold: 15 # train: 6353 # test: 334 AUC: 78.5 AUPRC: 79.6
# Fold: 16 # train: 6353 # test: 334 AUC: 79.9 AUPRC: 78.7
# Fold: 17 # train: 6353 # test: 334 AUC: 86.2 AUPRC: 84.5
# Fold: 18 # train: 6353 # test: 334 AUC: 79.6 AUPRC: 78.3
# Fold: 19 # train: 6354 # test: 333 AUC: 80.5 AUPRC: 79.2
# Fold: 20 # train: 6354 # test: 333 AUC: 77.2 AUPRC: 77.0
# Fold: 1 # train: 6352 # test: 335 AUC: 80.6 AUPRC: 78.5
# Fold: 2 # train: 6352 # test: 335 AUC: 80.1 AUPRC: 78.9
# Fold: 3 # train: 6352 # test: 335 AUC: 81.7 AUPRC: 81.3
# Fold: 4 # train: 6352 # test: 335 AUC: 82.1 AUPRC: 82.3
# Fold: 5 # train: 6352 # test: 335 AUC: 77.1 AUPRC: 76.3
# Fold: 6 # train: 6352 # test: 335 AUC: 80.6 AUPRC: 76.0
# Fold: 7 # train: 6352 # test: 335 AUC: 83.8 AUPRC: 84.0
# Fold: 8 # train: 6352 # test: 335 AUC: 84.0 AUPRC: 83.9
# Fold: 9 # train: 6352 # test: 335 AUC: 82.2 AUPRC: 81.2
# Fold: 10 # train: 6353 # test: 334 AUC: 80.1 AUPRC: 81.1
# Fold: 11 # train: 6353 # test: 334 AUC: 81.2 AUPRC: 80.1
# Fold: 12 # train: 6353 # test: 334 AUC: 81.1 AUPRC: 80.7
# Fold: 13 # train: 6353 # test: 334 AUC: 82.7 AUPRC: 81.3
# Fold: 14 # train: 6353 # test: 334 AUC: 80.4 AUPRC: 78.7
# Fold: 15 # train: 6353 # test: 334 AUC: 83.4 AUPRC: 82.3
# Fold: 16 # train: 6353 # test: 334 AUC: 79.4 AUPRC: 78.4
# Fold: 17 # train: 6353 # test: 334 AUC: 81.8 AUPRC: 78.2
# Fold: 18 # train: 6353 # test: 334 AUC: 79.4 AUPRC: 80.4
# Fold: 19 # train: 6354 # test: 333 AUC: 79.9 AUPRC: 79.9
# Fold: 20 # train: 6354 # test: 333 AUC: 82.9 AUPRC: 80.8
# Fold: 1 # train: 6352 # test: 335 AUC: 77.8 AUPRC: 78.4
# Fold: 2 # train: 6352 # test: 335 AUC: 81.9 AUPRC: 78.0
# Fold: 3 # train: 6352 # test: 335 AUC: 81.8 AUPRC: 80.3
# Fold: 4 # train: 6352 # test: 335 AUC: 84.9 AUPRC: 83.1
# Fold: 5 # train: 6352 # test: 335 AUC: 81.2 AUPRC: 82.6
# Fold: 6 # train: 6352 # test: 335 AUC: 81.1 AUPRC: 80.7
# Fold: 7 # train: 6352 # test: 335 AUC: 81.7 AUPRC: 81.5
# Fold: 8 # train: 6352 # test: 335 AUC: 78.2 AUPRC: 77.2
# Fold: 9 # train: 6352 # test: 335 AUC: 82.2 AUPRC: 80.7
# Fold: 10 # train: 6353 # test: 334 AUC: 80.9 AUPRC: 78.2
# Fold: 11 # train: 6353 # test: 334 AUC: 83.0 AUPRC: 82.9
# Fold: 12 # train: 6353 # test: 334 AUC: 83.7 AUPRC: 83.9
# Fold: 13 # train: 6353 # test: 334 AUC: 86.5 AUPRC: 87.4
# Fold: 14 # train: 6353 # test: 334 AUC: 79.0 AUPRC: 78.3
# Fold: 15 # train: 6353 # test: 334 AUC: 79.3 AUPRC: 79.6
# Fold: 16 # train: 6353 # test: 334 AUC: 76.7 AUPRC: 76.3
# Fold: 17 # train: 6353 # test: 334 AUC: 83.8 AUPRC: 82.8
# Fold: 18 # train: 6353 # test: 334 AUC: 82.8 AUPRC: 81.8
# Fold: 19 # train: 6354 # test: 333 AUC: 82.7 AUPRC: 82.3
# Fold: 20 # train: 6354 # test: 333 AUC: 78.7 AUPRC: 78.4
# Fold: 1 # train: 6352 # test: 335 AUC: 76.7 AUPRC: 77.3
# Fold: 2 # train: 6352 # test: 335 AUC: 84.5 AUPRC: 82.9
# Fold: 3 # train: 6352 # test: 335 AUC: 80.4 AUPRC: 81.5
# Fold: 4 # train: 6352 # test: 335 AUC: 83.7 AUPRC: 84.3
# Fold: 5 # train: 6352 # test: 335 AUC: 82.7 AUPRC: 82.1
# Fold: 6 # train: 6352 # test: 335 AUC: 78.6 AUPRC: 77.6
# Fold: 7 # train: 6352 # test: 335 AUC: 85.6 AUPRC: 85.6
# Fold: 8 # train: 6352 # test: 335 AUC: 78.5 AUPRC: 76.5
# Fold: 9 # train: 6352 # test: 335 AUC: 88.3 AUPRC: 88.7
# Fold: 10 # train: 6353 # test: 334 AUC: 80.3 AUPRC: 79.2
# Fold: 11 # train: 6353 # test: 334 AUC: 81.5 AUPRC: 81.8
# Fold: 12 # train: 6353 # test: 334 AUC: 88.0 AUPRC: 85.2
# Fold: 13 # train: 6353 # test: 334 AUC: 80.2 AUPRC: 79.3
# Fold: 14 # train: 6353 # test: 334 AUC: 80.3 AUPRC: 80.1
# Fold: 15 # train: 6353 # test: 334 AUC: 81.6 AUPRC: 80.3
# Fold: 16 # train: 6353 # test: 334 AUC: 76.5 AUPRC: 77.4
# Fold: 17 # train: 6353 # test: 334 AUC: 80.7 AUPRC: 77.7
# Fold: 18 # train: 6353 # test: 334 AUC: 79.0 AUPRC: 78.3
# Fold: 19 # train: 6354 # test: 333 AUC: 84.7 AUPRC: 83.9
# Fold: 20 # train: 6354 # test: 333 AUC: 83.0 AUPRC: 83.6
# Fold: 1 # train: 6352 # test: 335 AUC: 82.4 AUPRC: 80.6
# Fold: 2 # train: 6352 # test: 335 AUC: 80.0 AUPRC: 77.7
# Fold: 3 # train: 6352 # test: 335 AUC: 84.3 AUPRC: 83.2
# Fold: 4 # train: 6352 # test: 335 AUC: 80.9 AUPRC: 78.3
# Fold: 5 # train: 6352 # test: 335 AUC: 85.0 AUPRC: 85.1
# Fold: 6 # train: 6352 # test: 335 AUC: 79.9 AUPRC: 78.8
# Fold: 7 # train: 6352 # test: 335 AUC: 84.9 AUPRC: 83.3
# Fold: 8 # train: 6352 # test: 335 AUC: 80.5 AUPRC: 80.5
# Fold: 9 # train: 6352 # test: 335 AUC: 81.7 AUPRC: 79.6
# Fold: 10 # train: 6353 # test: 334 AUC: 83.0 AUPRC: 81.0
# Fold: 11 # train: 6353 # test: 334 AUC: 83.3 AUPRC: 82.6
# Fold: 12 # train: 6353 # test: 334 AUC: 82.4 AUPRC: 81.8
# Fold: 13 # train: 6353 # test: 334 AUC: 79.4 AUPRC: 79.5
# Fold: 14 # train: 6353 # test: 334 AUC: 81.8 AUPRC: 81.5
# Fold: 15 # train: 6353 # test: 334 AUC: 78.3 AUPRC: 77.1
# Fold: 16 # train: 6353 # test: 334 AUC: 81.5 AUPRC: 77.1
# Fold: 17 # train: 6353 # test: 334 AUC: 80.0 AUPRC: 80.5
# Fold: 18 # train: 6353 # test: 334 AUC: 79.9 AUPRC: 79.2
# Fold: 19 # train: 6354 # test: 333 AUC: 81.2 AUPRC: 80.9
# Fold: 20 # train: 6354 # test: 333 AUC: 80.2 AUPRC: 79.0
# AUC over runs: 81.5 (+/-0.2): [81.8, 81.7, 81.5, 81.4, 81.1, 81.7, 81.2, 81.4, 81.7, 81.5]

# %% [markdown]
# ## Putting it together
#
# ## Evaluating similarity-based drug repurposing via cross validation

# %%
n_proportion = 2 # proportion of negative instances compared to positives
n_fold = 10 # number of folds in cross-validation

# whether the drugs in the drug-disease pairs of the cross-validation folds should be non-overlapping disjoint_cv = False 
disjoint_cv = False 

# Check prediction accuracy of ML classifier on the data set using the parameters above
ml.check_ml(data, n_run, knn, n_fold, n_proportion, n_subset, model_type, prediction_type, features, recalculate_similarity, disjoint_cv, output_file, model_fun = None)
# Out:
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# AUC over runs: 84.1 (+/-0.3): [84.2, 83.6, 83.9, 84.1, 83.7, 84.7, 84.1, 83.7, 84.2, 84.5]
# ('AUC: 84.1', 'AUPRC: 83.5')

# %% [markdown]
# ## Revisiting cross-validation using disjoint folds

# %%
# whether the drugs in the drug-disease pairs of the cross-validation folds should be non-overlapping disjoint_cv = False 
disjoint_cv = True

# Check prediction accuracy of ML classifier on the data set using the parameters above
ml.check_ml(data, n_run, knn, n_fold, n_proportion, n_subset, model_type, prediction_type, features, recalculate_similarity, disjoint_cv, output_file, model_fun = None)
# Out:
# 536 drugs, 578 diseases, 309808 pairs, 2229 known associations
# AUC over runs: 64.3 (+/-1.0): [64.2, 63.7, 65.2, 63.2, 64.2, 66.1, 64.2, 63.2, 63.2, 65.7]
# ('AUC: 64.3', 'AUPRC: 61.8')
